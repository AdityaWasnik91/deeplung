# %%
# !python Prepare_data.py
# Out:
# 1
# 2
# 3
# 4
# tcmalloc: large alloc 2141192192 bytes == 0x244bea000 @  0x7f43076241e7 0x7f4304f785e1 0x7f4304fdcc78 0x7f4304fdfdb8 0x7f4304fe0395 0x7f430507765d 0x50a7f5 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f4307221b97 0x5b26fa
# tcmalloc: large alloc 2141192192 bytes == 0x3042ea000 @  0x7f43076241e7 0x7f4304f785e1 0x7f4304fdcc78 0x7f4304fdfdb8 0x7f4304fe0395 0x7f430507765d 0x50a7f5 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f4307221b97 0x5b26fa
# tcmalloc: large alloc 2141192192 bytes == 0x383cea000 @  0x7f43076241e7 0x7f4304f785e1 0x7f4304fdcc78 0x7f4304fdfdb8 0x7f4304fe0395 0x7f430507765d 0x50a7f5 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f4307221b97 0x5b26fa
# 2
# 3
# 4

# %%
# !python models.py
# Out:
# 2020-08-25 18:06:18.783677: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
# !python train_lung.py
# Out:
# 2020-08-25 18:55:25.058012: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# tcmalloc: large alloc 1497366528 bytes == 0x5254000 @  0x7f9fb582d1e7 0x7f9fb20495e1 0x7f9fb20b290d 0x7f9fb20b3522 0x7f9fb214abce 0x50a7f5 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f9fb542ab97 0x5b26fa
# tcmalloc: large alloc 1497366528 bytes == 0x5e654000 @  0x7f9fb582d1e7 0x7f9fb20495e1 0x7f9fb20b290d 0x7f9fb20b3522 0x7f9fb214abce 0x50a7f5 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f9fb542ab97 0x5b26fa
# Dataset loaded
# ...
