# %%
pwd
# Out:
# '/content'

# %%
cd  My\ Drive
# Out:
# [Errno 2] No such file or directory: 'My Drive'
# /content/drive/My Drive

# %%
# Out:
# '/content/drive/My Drive/Deeplung/Lung Segmentation'
